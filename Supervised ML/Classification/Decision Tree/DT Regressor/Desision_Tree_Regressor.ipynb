# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes
data=load_diabetes()

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
data.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
data.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
data.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
X=data.data

# %%
df=pd.DataFrame(data.data,columns=['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'])
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
y=data.target
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %% [markdown]
# **Train test split**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.28,random_state=18,shuffle=True)
X_train.shape,y_train.shape
# Out:
# ((318, 10), (318,))

# %% [markdown]
# **Model creation**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=18)
dtr
# Out:
# DecisionTreeRegressor(random_state=18)

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=18)

# %%
y_pred=dtr.predict(X_test)
y_pred
# Out:
# array([274.,  25., 292., 155., 155., 311., 150., 175.,  59., 190., 141.,
#        263.,  67.,  65.,  77., 115.,  25., 139., 170., 217., 182.,  89.,
#         97., 184., 217., 107., 160., 182.,  97., 186., 102., 178., 293.,
#         55., 132., 243., 104., 191., 276., 259., 128., 110.,  77., 174.,
#        191., 259., 132., 182.,  42., 268.,  59., 186., 174., 191., 115.,
#        122., 185.,  89., 109., 144., 180., 111.,  37., 182., 241., 144.,
#        235., 190., 296.,  64.,  88., 196., 222., 191.,  96., 167., 281.,
#         59., 235., 283., 192., 172., 311., 214., 170., 248., 200., 102.,
#         65., 174., 101., 115.,  31., 142., 131., 174., 104., 262., 162.,
#         72., 202.,  88.,  89.,  61.,  89., 246., 132., 219., 214.,  53.,
#        195., 200., 116., 190., 174., 245., 200., 118., 134.,  59.,  93.,
#        191., 214.,  99.])

# %%
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(50,50))
tree.plot_tree(dtr,filled=True)
# Out:
# [Text(0.6152051600693178, 0.96875, 'x[8] <= -0.0\nsquared_error = 5889.869\nsamples = 318\nvalue = 150.745'),
#  Text(0.3698068679314119, 0.90625, 'x[2] <= 0.008\nsquared_error = 3348.739\nsamples = 164\nvalue = 109.689'),
#  Text(0.27600556366289675, 0.84375, 'x[0] <= 0.029\nsquared_error = 2175.368\nsamples = 133\nvalue = 96.398'),
#  Text(0.1383847136081722, 0.78125, 'x[8] <= -0.043\nsquared_error = 1796.948\nsamples = 103\nvalue = 88.942'),
#  Text(0.03917365924844947, 0.71875, 'x[0] <= -0.095\nsquared_error = 1212.4\nsamples = 47\nvalue = 77.064'),
#  Text(0.014593214155417731, 0.65625, 'x[0] <= -0.098\nsquared_error = 2449.139\nsamples = 6\nvalue = 121.833'),
#  Text(0.008755928493250638, 0.59375, 'x[7] <= -0.021\nsquared_error = 598.222\nsamples = 3\nvalue = 79.667'),
#  Text(0.005837285662167092, 0.53125, 'x[3] <= -0.066\nsquared_error = 64.0\nsamples = 2\nvalue = 63.0'),
#  Text(0.002918642831083546, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Coefficient of Determination (R² score)
r2 = r2_score(y_test, y_pred)
print("R² score:", r2)
# Out:
# Mean Absolute Error (MAE): 69.95967741935483
# Mean Squared Error (MSE): 7472.798387096775
# Root Mean Squared Error (RMSE): 86.44534913514303
# R² score: -0.24238322543036928

# %% [markdown]
# # **Hyper parameter tuning**

# %% [markdown]
# criterion: str = "squared_error", splitter: str = "best", max_depth: Any | None = None, min_samples_split: int = 2, min_samples_leaf: int = 1, min_weight_fraction_leaf: float = 0, max_features: Any | None = None, random_state: Any | None = None, max_leaf_nodes: Any | None = None, min_impurity_decrease: float = 0, ccp_alpha: float = 0) -> None

# %%
params={
    'criterion':["squared_error", "friedman_mse", "absolute_error"],
    'splitter':["best", "random"],
    'max_depth':[1,2,3],
    'min_samples_split':[2,3,4],
    'min_samples_leaf':[1,2,3],
    'max_leaf_nodes':[2,3,4],
    'max_features': [ "sqrt", "log2"]
}
params
# Out:
# {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
#  'splitter': ['best', 'random'],
#  'max_depth': [1, 2, 3],
#  'min_samples_split': [2, 3, 4],
#  'min_samples_leaf': [1, 2, 3],
#  'max_leaf_nodes': [2, 3, 4],
#  'max_features': ['sqrt', 'log2']}

# %%
dtr=DecisionTreeRegressor( random_state=18)
dtr
# Out:
# DecisionTreeRegressor(random_state=18)

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
grid=GridSearchCV(estimator=dtr,param_grid=params,scoring='accuracy')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=18),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [2, 3, 4],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': 1,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 2,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
y_pred=grid.predict(X_test)
y_pred
# Out:
# array([132., 132., 132., 132., 132., 132., 132., 132., 132., 132., 132.,
#        132., 132., 132., 132., 132., 132., 132., 132., 192., 132., 132.,
#        132., 132., 192., 192., 132., 132., 132., 192., 132., 132., 132.,
#        132., 132., 192., 132., 132., 192., 132., 132., 132., 132., 192.,
#        132., 132., 132., 132., 132., 132., 132., 192., 132., 132., 132.,
#        132., 132., 132., 132., 132., 132., 132., 132., 132., 192., 132.,
#        132., 132., 132., 132., 132., 192., 192., 132., 192., 132., 132.,
#        132., 132., 132., 192., 132., 132., 132., 192., 132., 132., 132.,
#        192., 132., 132., 132., 132., 132., 132., 132., 132., 132., 132.,
#        132., 192., 132., 132., 132., 132., 192., 132., 132., 132., 132.,
#        132., 132., 132., 132., 132., 132., 132., 132., 132., 132., 132.,
#        132., 132., 132.])

# %%
best=grid.best_estimator_
best
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=1,
#                       max_features='sqrt', max_leaf_nodes=2, random_state=18,
#                       splitter='random')

# %%
tree.plot_tree(best)
# Out:
# [Text(0.5, 0.75, 'x[4] <= 0.06\nabsolute_error = 65.211\nsamples = 318\nvalue = 139.0'),
#  Text(0.25, 0.25, 'absolute_error = 64.889\nsamples = 287\nvalue = 132.0'),
#  Text(0.75, 0.25, 'absolute_error = 53.806\nsamples = 31\nvalue = 192.0')]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Coefficient of Determination (R² score)
r2 = r2_score(y_test, y_pred)
print("R² score:", r2)
# Out:
# Mean Absolute Error (MAE): 66.91935483870968
# Mean Squared Error (MSE): 6636.274193548387
# Root Mean Squared Error (RMSE): 81.4633303612637
# R² score: -0.10330766472399366

# %%
rand=RandomizedSearchCV(estimator=dtr,param_distributions=params,scoring='accuracy',)
rand.fit(X_train,y_train)
y_pred=rand.predict(X_test)
best=rand.best_estimator_
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_Stest, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Coefficient of Determination (R² score)
r2 = r2_score(y_test, y_pred)
print("R² score:", r2)
# Out:
# Mean Absolute Error (MAE): 66.91935483870968
# Mean Squared Error (MSE): 6636.274193548387
# Root Mean Squared Error (RMSE): 81.4633303612637
# R² score: -0.10330766472399366

# %%
best=rand.best_estimator_
best
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_depth=3,
#                       max_features='log2', max_leaf_nodes=2, min_samples_leaf=2,
#                       min_samples_split=4, random_state=18, splitter='random')

# %%
tree.plot_tree(best)
plt.show()
