# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_classification
X,y=make_classification(n_samples=1000,random_state=18,n_classes=2)
X.shape,y.shape
# Out:
# ((1000, 20), (1000,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=18)
X_train.shape,X_test.shape
# Out:
# ((700, 20), (300, 20))

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_prob=lr.predict_proba(X_test)[:,1]
y_prob
# Out:
# array([6.09481692e-01, 8.69049402e-01, 5.13880195e-01, 7.79155937e-01,
#        9.53763693e-01, 5.23371707e-02, 2.27798944e-01, 7.89414982e-01,
#        7.37153166e-01, 3.12432946e-01, 9.66429807e-01, 6.70886251e-01,
#        4.09035559e-03, 4.99348174e-01, 7.19685542e-01, 1.79677466e-01,
#        6.44532615e-02, 9.51302573e-01, 8.87594368e-01, 4.78670238e-01,
#        9.94351302e-01, 2.55100825e-01, 5.14687151e-02, 1.02716434e-01,
#        9.78699474e-01, 4.51163446e-03, 9.99621566e-01, 9.37636579e-01,
#        1.18205899e-02, 9.69815648e-01, 8.68860386e-01, 9.88425960e-01,
#        6.15386217e-01, 1.47861315e-01, 3.13107956e-01, 1.65068635e-01,
#        7.00879021e-02, 4.04990461e-01, 4.55216957e-02, 2.76644921e-01,
#        1.86180808e-02, 9.48335029e-01, 5.57855688e-02, 4.53883696e-01,
#        5.01082578e-01, 1.14053327e-02, 9.92329663e-01, 5.40825311e-03,
#        8.59728848e-01, 9.90284006e-01, 7.62683856e-02, 7.65669897e-02,
#        1.00177571e-02, 9.96565353e-01, 9.96836685e-01, 6.70657460e-01,
#        1.45137385e-02, 7.91307096e-02, 8.06780657e-01, 1.68322012e-01,
#        7.66678412e-01, 1.29900079e-01, 9.83891043e-02, 9.99679144e-01,
#        9.99478816e-01, 4.95266000e-02, 9.86744613e-01, 7.47492840e-01,
#        7.38457435e-01, 2.71101786e-01, 1.18199066e-01, 4.43704031e-01,
#        4.66409443e-01, 1.17682191e-01, 1.15431215e-01, 9.35846173e-01,
#        1.46245086e-01, 4.81596691e-01, 9.00736771e-01, 5.46304287e-02,
#        6.79844327e-02, 1.53237904e-01, 4.34802427e-02, 9.95812538e-01,
#        9.56905769e-01, 6.06245922e-01, 7.01747933e-02, 1.52110055e-02,
#        3.91685626e-02, 5.63182498e-01, 7.81439408e-01, 5.66907175e-03,
#        1.87849148e-02, 6.19114173e-02, 9.04140593e-01, 1.35929109e-01,
#        7.28258971e-01, 3.38503229e-01, 7.16865457e-01, 2.95606757e-01,
#        9.96001679e-01, 9.10863119e-01, 3.01256966e-02, 1.72061439e-01,
#        9.89326044e-01, 9.55263279e-02, 9.49609674e-01, 3.52325714e-01,
#        4.62333237e-02, 3.24443078e-03, 1.44374753e-01, 2.62198469e-02,
#        6.57829102e-02, 5.33364576e-01, 1.36195607e-01, 8.03105170e-01,
#        7.74006112e-01, 5.19815555e-02, 9.19879797e-01, 2.69479933e-01,
#        9.74323345e-01, 9.97135228e-01, 2.34440718e-01, 2.20067506e-02,
#        9.97574836e-01, 9.96869629e-01, 8.33164217e-01, 9.13215888e-03,
#        2.39662737e-01, 5.18907073e-01, 3.54051153e-03, 9.67846933e-01,
#        9.98071746e-01, 9.99089852e-02, 9.90294836e-01, 9.28647503e-01,
#        1.46715585e-02, 7.87773224e-01, 1.54171969e-01, 2.14811035e-01,
#        4.94053349e-02, 9.33417223e-01, 2.14721718e-01, 9.88134785e-01,
#        4.67737289e-01, 9.83844941e-01, 9.64161422e-01, 8.34987171e-02,
#        9.86326781e-04, 7.56248113e-01, 1.83672298e-02, 3.29037633e-02])

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,threshold=roc_curve(y_test,y_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00666667, 0.00666667,
#        0.01333333, 0.01333333, 0.02      , 0.02      , 0.03333333,
#        0.03333333, 0.05333333, 0.05333333, 0.08      , 0.08      ,
#        0.1       , 0.1       , 0.12666667, 0.12666667, 0.14      ,
#        0.14      , 0.15333333, 0.15333333, 0.16666667, 0.16666667,
#        0.27333333, 0.27333333, 0.32666667, 0.32666667, 0.39333333,
#        0.39333333, 0.4       , 0.4       , 0.49333333, 0.49333333,
#        0.5       , 0.5       , 0.51333333, 0.51333333, 0.7       ,
#        0.7       , 0.76      , 0.76      , 0.77333333, 0.77333333,
#        1.        , 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.00666667, 0.49333333, 0.49333333, 0.79333333,
#        0.79333333, 0.82      , 0.82      , 0.85333333, 0.85333333,
#        0.86666667, 0.86666667, 0.87333333, 0.87333333, 0.88      ,
#        0.88      , 0.88666667, 0.88666667, 0.89333333, 0.89333333,
#        0.9       , 0.9       , 0.90666667, 0.90666667, 0.91333333,
#        0.91333333, 0.92      , 0.92      , 0.92666667, 0.92666667,
#        0.93333333, 0.93333333, 0.94666667, 0.94666667, 0.95333333,
#        0.95333333, 0.96      , 0.96      , 0.96666667, 0.96666667,
#        0.97333333, 0.97333333, 0.98      , 0.98      , 0.99333333,
#        0.99333333, 1.        ])

# %%
threshold
# Out:
# array([           inf, 9.99999903e-01, 9.82118123e-01, 9.81735350e-01,
#        8.57629003e-01, 8.45785143e-01, 7.90552342e-01, 7.50368310e-01,
#        6.16750114e-01, 5.94334472e-01, 5.48151066e-01, 4.05643309e-01,
#        4.02413420e-01, 3.54057784e-01, 3.39391851e-01, 3.19837902e-01,
#        3.12330073e-01, 2.70921564e-01, 2.60593865e-01, 2.57567448e-01,
#        2.54443153e-01, 2.35796797e-01, 2.27779433e-01, 1.90736905e-01,
#        1.81009747e-01, 1.11550192e-01, 1.04533037e-01, 7.19321612e-02,
#        7.11507547e-02, 5.71174956e-02, 5.53967392e-02, 5.08866063e-02,
#        4.62480826e-02, 3.31665171e-02, 3.12896585e-02, 3.11851437e-02,
#        2.71394110e-02, 2.69728913e-02, 2.69198599e-02, 6.94047163e-03,
#        6.80299424e-03, 4.73850020e-03, 4.43661763e-03, 4.24800591e-03,
#        4.14231948e-03, 3.88137453e-05, 2.20526429e-05])

# %%
roc_auc=auc(fpr,tpr)
roc_auc
# Out:
# 0.9141713014460511

# %% [markdown]
# Plotting curve

# %%
# Plot ROC curve

fig=plt.figure(figsize=(20, 50))
ax=fig.add_subplot(111)
for xyz in zip(fpr,tpr,threshold):
  ax.annotate('%s' %np.round(xyz[2],2),xy=(xyz[0],xyz[1]))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()
